# %% [markdown]
# ## Entrenamiento con GAE de AC2s mejorando entre ellos
# A ver si aprende con más info que solo si la acción es buena o no

# %%
from competition import train_multi_agents, A2C

agents = [A2C(f"A2c_{i+3}") for i in range(4)]
train_multi_agents(agents, episodes=1000)
# Out:
# ./A2c_3.pth True
# ./A2c_4.pth True
# ./A2c_5.pth True
# ./A2c_6.pth True
# Entrenamiento finalizado para todos los agentes.

# %%
from competition import tournament, A2C, RandomAgent, Blocker, Selfish, Minimax
tournament(
    agents=[A2C(name=f'A2c_{i+3}') for i in range(4)]+[RandomAgent(name=f'Random'), Blocker(name=f'Blocker'),
                                                     Selfish(name=f'Selfish'), Minimax(name=f'Minimax')],
    competitors_per_round=4,
    num_rounds=10,
    max_score=10,
    score_to_substract=5,
    max_training_rounds=0
)
# Out:
# ./A2c_3.pth True
# ./A2c_4.pth True
# ./A2c_5.pth True
# ./A2c_6.pth True
# Ronda 1: A2c_6 vs. Random vs. Blocker vs. Selfish
# Jugamos
# Ronda 2: A2c_5 vs. A2c_6 vs. Blocker vs. Minimax
# Jugamos
# Ronda 3: A2c_4 vs. A2c_6 vs. Selfish vs. Minimax
# Jugamos
# Ronda 4: A2c_4 vs. A2c_5 vs. Random vs. Minimax
# Jugamos
# Ronda 5: A2c_3 vs. A2c_4 vs. Selfish vs. Minimax
# Jugamos
# Ronda 6: A2c_5 vs. Random vs. Selfish vs. Minimax
# Jugamos
# Ronda 7: A2c_4 vs. A2c_5 vs. Random vs. Blocker
# Jugamos
# Ronda 8: A2c_3 vs. A2c_4 vs. A2c_6 vs. Selfish
# Jugamos
# Ronda 9: A2c_3 vs. A2c_4 vs. A2c_6 vs. Blocker
# Jugamos
# 	Se han necesitado 2 rondas adicionales
# Ronda 10: A2c_3 vs. Random vs. Blocker vs. Minimax
# Jugamos
# Ronda 11: A2c_3 vs. A2c_4 vs. Random vs. Minimax
# Jugamos
# Ronda 12: A2c_5 vs. Random vs. Blocker vs. Minimax
# Jugamos
# Ronda 13: A2c_3 vs. Random vs. Selfish vs. Minimax
# Jugamos
# Ronda 14: A2c_4 vs. A2c_6 vs. Blocker vs. Selfish
# Jugamos
# Ronda 15: A2c_4 vs. Random vs. Blocker vs. Selfish
# Jugamos
# Ronda 16: A2c_5 vs. A2c_6 vs. Random vs. Blocker
# Jugamos
# 	Se han necesitado 48 rondas adicionales
# Ronda 17: A2c_3 vs. Random vs. Blocker vs. Selfish
# Jugamos
# Ronda 18: A2c_4 vs. A2c_6 vs. Random vs. Selfish
# Jugamos
# Ronda 19: A2c_3 vs. A2c_5 vs. Random vs. Blocker
# Jugamos
# Ronda 20: A2c_3 vs. A2c_4 vs. A2c_5 vs. Selfish
# Jugamos
# Ronda 21: A2c_3 vs. A2c_5 vs. A2c_6 vs. Selfish
# Jugamos
# Ronda 22: A2c_3 vs. A2c_4 vs. A2c_5 vs. Blocker
# Jugamos
# Ronda 23: A2c_3 vs. A2c_6 vs. Random vs. Minimax
# Jugamos
# Ronda 24: A2c_6 vs. Random vs. Blocker vs. Minimax
# Jugamos
# Ronda 25: A2c_3 vs. A2c_6 vs. Random vs. Blocker
# Jugamos
# 	Se ha necesitado una ronda adicional
# Ronda 26: A2c_3 vs. A2c_5 vs. A2c_6 vs. Blocker
# Jugamos
# Ronda 27: A2c_3 vs. A2c_5 vs. Random vs. Minimax
# Jugamos
# Ronda 28: A2c_5 vs. A2c_6 vs. Selfish vs. Minimax
# Jugamos
# Ronda 29: Random vs. Blocker vs. Selfish vs. Minimax
# Jugamos
# Ronda 30: A2c_4 vs. A2c_6 vs. Random vs. Minimax
# Jugamos
# Ronda 31: A2c_3 vs. A2c_5 vs. Random vs. Selfish
# Jugamos
# Ronda 32: A2c_4 vs. A2c_5 vs. A2c_6 vs. Blocker
# Jugamos
# Ronda 33: A2c_3 vs. A2c_5 vs. Selfish vs. Minimax
# Jugamos
# Ronda 34: A2c_5 vs. Blocker vs. Selfish vs. Minimax
# Jugamos
# 	Se han necesitado 6 rondas adicionales
# Ronda 35: A2c_4 vs. A2c_6 vs. Random vs. Blocker
# Jugamos
# 	Se han necesitado 4 rondas adicionales
# Ronda 36: A2c_3 vs. A2c_4 vs. A2c_5 vs. Minimax
# Jugamos
# Ronda 37: A2c_5 vs. A2c_6 vs. Blocker vs. Selfish
# Jugamos
# Ronda 38: A2c_5 vs. A2c_6 vs. Random vs. Selfish
# Jugamos
# Ronda 39: A2c_3 vs. Blocker vs. Selfish vs. Minimax
# Jugamos
# Ronda 40: A2c_5 vs. Random vs. Blocker vs. Selfish
# Jugamos
# 	Se han necesitado 8 rondas adicionales
# Ronda 41: A2c_4 vs. Blocker vs. Selfish vs. Minimax
# Jugamos
# 	Se ha necesitado una ronda adicional
# Ronda 42: A2c_4 vs. A2c_5 vs. A2c_6 vs. Random
# Jugamos
# Ronda 43: A2c_3 vs. A2c_4 vs. A2c_6 vs. Random
# Jugamos
# 	Se han necesitado 2 rondas adicionales
# Ronda 44: A2c_6 vs. Blocker vs. Selfish vs. Minimax
# Jugamos
# Ronda 45: A2c_3 vs. A2c_4 vs. Random vs. Selfish
# Jugamos
# Ronda 46: A2c_3 vs. A2c_5 vs. A2c_6 vs. Random
# Jugamos
# 	Se han necesitado 4 rondas adicionales
# Ronda 47: A2c_3 vs. A2c_4 vs. Blocker vs. Selfish
# Jugamos
# Ronda 48: A2c_4 vs. A2c_5 vs. A2c_6 vs. Selfish
# Jugamos
# Ronda 49: A2c_3 vs. A2c_4 vs. Random vs. Blocker
# Jugamos
# Ronda 50: A2c_3 vs. A2c_4 vs. A2c_6 vs. Minimax
# Jugamos
# Ronda 51: A2c_4 vs. A2c_5 vs. Blocker vs. Selfish
# Jugamos
# Ronda 52: A2c_3 vs. A2c_5 vs. Blocker vs. Selfish
# Jugamos
# Ronda 53: A2c_3 vs. A2c_4 vs. A2c_5 vs. A2c_6
# Jugamos
# 	Se han necesitado 4 rondas adicionales
# Ronda 54: A2c_4 vs. A2c_5 vs. Selfish vs. Minimax
# Jugamos
# Ronda 55: A2c_6 vs. Random vs. Selfish vs. Minimax
# Jugamos
# Ronda 56: A2c_4 vs. Random vs. Selfish vs. Minimax
# Jugamos
# 	Se han necesitado 14 rondas adicionales
# Ronda 57: A2c_3 vs. A2c_4 vs. Blocker vs. Minimax
# Jugamos
# Ronda 58: A2c_3 vs. A2c_4 vs. A2c_5 vs. Random
# Jugamos
# Ronda 59: A2c_3 vs. A2c_5 vs. A2c_6 vs. Minimax
# Jugamos
# Ronda 60: A2c_4 vs. A2c_5 vs. A2c_6 vs. Minimax
# Jugamos
# Ronda 61: A2c_3 vs. A2c_6 vs. Selfish vs. Minimax
# Jugamos
# Ronda 62: A2c_4 vs. A2c_5 vs. Random vs. Selfish
# Jugamos
# Ronda 63: A2c_3 vs. A2c_6 vs. Blocker vs. Minimax
# Jugamos
# Ronda 64: A2c_4 vs. A2c_5 vs. Blocker vs. Minimax
# Jugamos
# Ronda 65: A2c_4 vs. A2c_6 vs. Blocker vs. Minimax
# Jugamos
# Ronda 66: A2c_3 vs. A2c_6 vs. Blocker vs. Selfish
# Jugamos
# Ronda 67: A2c_3 vs. A2c_6 vs. Random vs. Selfish
# Jugamos
# Ronda 68: A2c_4 vs. Random vs. Blocker vs. Minimax
# Jugamos
# Ronda 69: A2c_3 vs. A2c_5 vs. Blocker vs. Minimax
# Jugamos
# Ronda 70: A2c_5 vs. A2c_6 vs. Random vs. Minimax
# Jugamos
#
# CLASIFICACIÓN FINAL
# Agente |  Puntos
# ------------------
# Selfish |     325
# Minimax |     275
# Blocker |     160
# Random |      65
#  A2c_6 |      50
#  A2c_5 |      20
#  A2c_3 |      15
#  A2c_4 |     -10
# ------------------

# %%
from competition import tournament, A2C, RandomAgent, Blocker, Selfish, Minimax
tournament(
    agents=[A2C(name=f'A2c_{i}') for i in range(7)],
    competitors_per_round=4,
    num_rounds=10,
    max_score=10,
    score_to_substract=5,
    max_training_rounds=0
)
# Out:
# ./A2c_0.pth True
# ./A2c_1.pth True
# ./A2c_3.pth True
# ./A2c_5.pth True
# Ronda 1: A2c_3 vs. A2c_4 vs. A2c_5 vs. A2c_6
# Jugamos
# Ronda 2: A2c_2 vs. A2c_3 vs. A2c_5 vs. A2c_6
# Jugamos
# Ronda 3: A2c_0 vs. A2c_3 vs. A2c_4 vs. A2c_6
# Jugamos
# 	Se han necesitado 2 rondas adicionales
# Ronda 4: A2c_1 vs. A2c_2 vs. A2c_3 vs. A2c_4
# Jugamos
# 	Se han necesitado 8 rondas adicionales
# Ronda 5: A2c_0 vs. A2c_2 vs. A2c_4 vs. A2c_5
# Jugamos
# 	Se han necesitado 5 rondas adicionales
# Ronda 6: A2c_2 vs. A2c_3 vs. A2c_4 vs. A2c_6
# Jugamos
# Ronda 7: A2c_1 vs. A2c_4 vs. A2c_5 vs. A2c_6
# Jugamos
# 	Se han necesitado 3 rondas adicionales
# Ronda 8: A2c_0 vs. A2c_1 vs. A2c_3 vs. A2c_5
# Jugamos
# 	Se han necesitado 4 rondas adicionales
# Ronda 9: A2c_0 vs. A2c_1 vs. A2c_2 vs. A2c_4
# Jugamos
# Ronda 10: A2c_1 vs. A2c_3 vs. A2c_4 vs. A2c_5
# Jugamos
# Ronda 11: A2c_2 vs. A2c_4 vs. A2c_5 vs. A2c_6
# Jugamos
# 	Se han necesitado 4 rondas adicionales
# Ronda 12: A2c_0 vs. A2c_1 vs. A2c_4 vs. A2c_5
# Jugamos
# 	Se han necesitado 2 rondas adicionales
# Ronda 13: A2c_0 vs. A2c_2 vs. A2c_4 vs. A2c_6
# Jugamos
# Ronda 14: A2c_0 vs. A2c_2 vs. A2c_3 vs. A2c_5
# Jugamos
# 	Se han necesitado 12 rondas adicionales
# Ronda 15: A2c_0 vs. A2c_1 vs. A2c_3 vs. A2c_4
# Jugamos
# 	Se han necesitado 8 rondas adicionales
# Ronda 16: A2c_0 vs. A2c_2 vs. A2c_3 vs. A2c_6
# Jugamos
# 	Se han necesitado 2 rondas adicionales
# Ronda 17: A2c_0 vs. A2c_4 vs. A2c_5 vs. A2c_6
# Jugamos
# 	Se han necesitado 3 rondas adicionales
# Ronda 18: A2c_0 vs. A2c_1 vs. A2c_2 vs. A2c_3
# Jugamos
# 	Se han necesitado 8 rondas adicionales
# Ronda 19: A2c_0 vs. A2c_2 vs. A2c_5 vs. A2c_6
# Jugamos
# 	Se han necesitado 7 rondas adicionales
# Ronda 20: A2c_1 vs. A2c_2 vs. A2c_5 vs. A2c_6
# Jugamos
# 	Se han necesitado 7 rondas adicionales
# Ronda 21: A2c_0 vs. A2c_1 vs. A2c_5 vs. A2c_6
# Jugamos
# 	Se han necesitado 2 rondas adicionales
# Ronda 22: A2c_1 vs. A2c_2 vs. A2c_3 vs. A2c_5
# Jugamos
# 	Se han necesitado 5 rondas adicionales
# Ronda 23: A2c_2 vs. A2c_3 vs. A2c_4 vs. A2c_5
# Jugamos
# Ronda 24: A2c_0 vs. A2c_1 vs. A2c_2 vs. A2c_5
# Jugamos
# Ronda 25: A2c_1 vs. A2c_2 vs. A2c_3 vs. A2c_6
# Jugamos
# 	Se han necesitado 3 rondas adicionales
# Ronda 26: A2c_0 vs. A2c_1 vs. A2c_2 vs. A2c_6
# Jugamos
# 	Se han necesitado 3 rondas adicionales
# Ronda 27: A2c_0 vs. A2c_1 vs. A2c_3 vs. A2c_6
# Jugamos
# 	Se han necesitado 2 rondas adicionales
# Ronda 28: A2c_0 vs. A2c_2 vs. A2c_3 vs. A2c_4
# Jugamos
# Ronda 29: A2c_0 vs. A2c_3 vs. A2c_5 vs. A2c_6
# Jugamos
# 	Se han necesitado 8 rondas adicionales
# Ronda 30: A2c_1 vs. A2c_2 vs. A2c_4 vs. A2c_6
# Jugamos
# 	Se han necesitado 20 rondas adicionales
# Ronda 31: A2c_1 vs. A2c_3 vs. A2c_5 vs. A2c_6
# Jugamos
# 	Se han necesitado 5 rondas adicionales
# Ronda 32: A2c_0 vs. A2c_3 vs. A2c_4 vs. A2c_5
# Jugamos
# Ronda 33: A2c_0 vs. A2c_1 vs. A2c_4 vs. A2c_6
# Jugamos
# 	Se ha necesitado una ronda adicional
# Ronda 34: A2c_1 vs. A2c_2 vs. A2c_4 vs. A2c_5
# Jugamos
# 	Se ha necesitado una ronda adicional
# Ronda 35: A2c_1 vs. A2c_3 vs. A2c_4 vs. A2c_6
# Jugamos
# 	Se han necesitado 4 rondas adicionales
#
# CLASIFICACIÓN FINAL
# Agente |  Puntos
# ------------------
#  A2c_1 |     105
#  A2c_2 |      65
#  A2c_4 |      55
#  A2c_6 |      55
#  A2c_5 |      40
#  A2c_0 |      30
#  A2c_3 |      30
# ------------------

# %% [markdown]
# No aprende nada ):
#
# Lo he ejecutado después de borrar la memoria de los peores, el 2, 4 y 6 y han quedado de los mejores, es decir, no aprenden nada

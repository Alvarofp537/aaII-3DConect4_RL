# %% [markdown]
# #### Entrenamiento solas

# %%
from competition import tournament, DQN
tournament(
    agents=[DQN(name=f'DQN_{i}') for i in range(4)],
    competitors_per_round=4,
    num_rounds=10,
    max_score=10,
    score_to_substract=5,
    min_training_rounds=50000
)
# Out:
# Cargando modelo desde ./DQN_0.pth
# Cargando modelo desde ./DQN_1.pth
# Cargando modelo desde ./DQN_2.pth
# Cargando modelo desde ./DQN_3.pth
# Ronda 1: DQN_0 vs. DQN_1 vs. DQN_2 vs. DQN_3
# Entrenando: 50000 de 50000 rondas
# Entrenamiento finalizado con 50000 rondas
# Victorias acumuladas:
# 	DQN_0: 18891
# 	DQN_1: 595
# 	DQN_2: 10507
# 	DQN_3: 20007
# Jugamos
#
# CLASIFICACIÓN FINAL
# Agente |  Puntos
# ------------------
#  DQN_0 |      10
#  DQN_3 |       5
#  DQN_1 |       0
#  DQN_2 |       0
# ------------------

# %% [markdown]
# #### Competición 2 DQN vs 3 Random
#
# Aprende lo básico

# %%
from competition import tournament, RandomAgent, DQN
tournament(
    agents=[RandomAgent(name=f'Random_{i}') for i in range(3)]+[DQN(name=f'DQN_{i}') for i in range(2)],
    competitors_per_round=4,
    num_rounds=10,
    max_score=10,
    score_to_substract=5,
)
# Out:
# Cargando modelo desde ./DQN_0.pth
# Cargando modelo desde ./DQN_1.pth
# Ronda 1: Random_0 vs. Random_1 vs. Random_2 vs. DQN_0
# Entrenando: 60 de 60 rondas
# Entrenamiento finalizado con 60 rondas
# Victorias acumuladas:
# 	Random_0: 11
# 	Random_1: 4
# 	Random_2: 5
# 	DQN_0: 40
# Jugamos
# Ronda 2: Random_1 vs. Random_2 vs. DQN_0 vs. DQN_1
# Entrenando: 545 de 545 rondas
# Entrenamiento finalizado con 545 rondas
# Victorias acumuladas:
# 	Random_1: 7
# 	Random_2: 5
# 	DQN_0: 357
# 	DQN_1: 176
# Jugamos
# Ronda 3: Random_0 vs. Random_2 vs. DQN_0 vs. DQN_1
# Entrenando: 792 de 792 rondas
# Entrenamiento finalizado con 792 rondas
# Victorias acumuladas:
# 	Random_0: 13
# 	Random_2: 13
# 	DQN_0: 531
# 	DQN_1: 235
# Jugamos
# Ronda 4: Random_0 vs. Random_1 vs. DQN_0 vs. DQN_1
# Entrenando: 790 de 790 rondas
# Entrenamiento finalizado con 790 rondas
# Victorias acumuladas:
# 	Random_0: 11
# 	Random_1: 11
# 	DQN_0: 506
# 	DQN_1: 262
# Jugamos
# ...

# %% [markdown]
# #### Competición 3 DQN vs 3 Blocker
#
# Aprende a ganar aunque le bloqueen

# %%
from competition import tournament, DQN, Blocker
tournament(
    agents=[DQN(name=f'DQN_{i}') for i in range(3)]+[Blocker(name=f'Blocker_{i}') for i in range(3)],
    competitors_per_round=4,
    num_rounds=10,
    max_score=3,
    score_to_substract=1,
    min_training_rounds=300,
    max_training_rounds=700
)
# Out:
# Cargando modelo desde ./DQN_0.pth
# Cargando modelo desde ./DQN_1.pth
# Cargando modelo desde ./DQN_2.pth
# Ronda 1: DQN_0 vs. DQN_2 vs. Blocker_0 vs. Blocker_1
# Entrenando: 675 de 675 rondas
# Entrenamiento finalizado con 675 rondas
# Victorias acumuladas:
# 	DQN_0: 2
# 	DQN_2: 12
# 	Blocker_0: 334
# 	Blocker_1: 315
# Jugamos
# 	Se han necesitado 2 rondas adicionales
# Ronda 2: DQN_1 vs. Blocker_0 vs. Blocker_1 vs. Blocker_2
# Entrenando: 300 de 300 rondas
# Entrenamiento finalizado con 300 rondas
# Victorias acumuladas:
# 	DQN_1: 0
# 	Blocker_0: 91
# 	Blocker_1: 62
# 	Blocker_2: 65
# Jugamos
# Ronda 3: DQN_0 vs. DQN_1 vs. DQN_2 vs. Blocker_1
# Entrenando: 1471 de 1471 rondas
# Entrenamiento finalizado con 1471 rondas
# Victorias acumuladas:
# 	DQN_0: 776
# 	DQN_1: 80
# 	DQN_2: 38
# 	Blocker_1: 577
# Jugamos
# 	Se ha necesitado una ronda adicional
# Ronda 4: DQN_0 vs. DQN_1 vs. Blocker_1 vs. Blocker_2
# Entrenando: 203 de 1788 rondas
# ...

# %% [markdown]
# #### Competición 3 A2C vs vs 3 Selfish
#
# Aprende bloquear

# %%
from competition import tournament, DQN, Selfish
tournament(
    agents=[DQN(name=f'DQN_{i}') for i in range(3)]+[Selfish(name=f'Selfish_{i}') for i in range(3)],
    competitors_per_round=4,
    num_rounds=10,
    max_score=10,
    score_to_substract=5,
    max_training_rounds=500
)
# Out:
# Cargando modelo desde ./DQN_0.pth
# Cargando modelo desde ./DQN_1.pth
# Cargando modelo desde ./DQN_2.pth
# Ronda 1: DQN_0 vs. DQN_1 vs. Selfish_0 vs. Selfish_1
# Entrenando: 1376 de 1376 rondas
# Entrenamiento finalizado con 1376 rondas
# Victorias acumuladas:
# 	DQN_0: 917
# 	DQN_1: 23
# 	Selfish_0: 413
# 	Selfish_1: 23
# Jugamos
# Ronda 2: DQN_1 vs. DQN_2 vs. Selfish_1 vs. Selfish_2
# Entrenando: 960 de 960 rondas
# Entrenamiento finalizado con 960 rondas
# Victorias acumuladas:
# 	DQN_1: 75
# 	DQN_2: 74
# 	Selfish_1: 791
# 	Selfish_2: 20
# Jugamos
# Ronda 3: DQN_0 vs. DQN_2 vs. Selfish_0 vs. Selfish_1
# Entrenando: 500 de 500 rondas
# Entrenamiento finalizado con 500 rondas
# Victorias acumuladas:
# 	DQN_0: 303
# 	DQN_2: 52
# 	Selfish_0: 131
# 	Selfish_1: 14
# Jugamos
# Ronda 4: DQN_0 vs. DQN_1 vs. DQN_2 vs. Selfish_0
# Entrenando: 1441 de 1441 rondas
# Entrenamiento finalizado con 1441 rondas
# Victorias acumuladas:
# 	DQN_0: 1055
# 	DQN_1: 109
# 	DQN_2: 119
# 	Selfish_0: 158
# ...

# %% [markdown]
# #### Competición 3 DQN vs 3 Minimax
#
# Jugamos contra minimax (inteligentes)

# %%
from competition import tournament, DQN, Minimax
tournament(
    agents=[DQN(name=f'DQN_{i}') for i in range(3)]+[Minimax(name=f'Minimax_{i}') for i in range(3)],
    competitors_per_round=4,
    num_rounds=10,
    max_score=10,
    score_to_substract=5,
    min_training_rounds=500
)
# Out:
# Cargando modelo desde ./DQN_0.pth
# Cargando modelo desde ./DQN_1.pth
# Cargando modelo desde ./DQN_2.pth
# Ronda 1: DQN_0 vs. DQN_1 vs. Minimax_0 vs. Minimax_2
# Entrenando: 670 de 1123 rondas
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[4], line 2
#       1 from competition import tournament, DQN, Minimax
# ----> 2 tournament(
#       3     agents=[DQN(name=f'DQN_{i}') for i in range(3)]+[Minimax(name=f'Minimax_{i}') for i in range(3)],
#       4     competitors_per_round=4,
#       5     num_rounds=10,
#       6     max_score=10,
#       7     score_to_substract=5,
#       8     min_training_rounds=500
#       9 )
#
# File ~/Escritorio/aaII-3DConect4_RL/competition.py:122, in tournament(agents, competitors_per_round, num_rounds, max_score, score_to_substract, max_training_rounds, min_training_rounds, imprimir)
# ...

# %% [markdown]
# #### Competición 2 DQN vs 1 Random vs 1 Blocker vs 1 Selfish vs 1 Minimax
#
# Todos juntos sin aprender (control)

# %%
from competition import tournament, DQN, RandomAgent, Blocker, Selfish, Minimax
tournament(
    agents=[DQN(name=f'DQN_{i}') for i in range(2)]+[RandomAgent(name=f'Random'), Blocker(name=f'Blocker'), Selfish(name=f'Selfish')],#, Minimax(name=f'Minimax',depth= 3)],
    competitors_per_round=4,
    num_rounds=10,
    max_score=3,
    score_to_substract=1,
    min_training_rounds=1000,
)
# Out:
# Cargando modelo desde ./DQN_0.pth
# Cargando modelo desde ./DQN_1.pth
# Ronda 1: DQN_0 vs. Random vs. Blocker vs. Selfish
# Entrenando: 1000 de 1000 rondas
# Entrenamiento finalizado con 1000 rondas
# Victorias acumuladas:
# 	DQN_0: 211
# 	Random: 29
# 	Blocker: 65
# 	Selfish: 695
# Jugamos
# 	Se han necesitado 22 rondas adicionales
# Ronda 2: DQN_0 vs. DQN_1 vs. Blocker vs. Selfish
# Entrenando: 1000 de 1000 rondas
# Entrenamiento finalizado con 1000 rondas
# Victorias acumuladas:
# 	DQN_0: 457
# 	DQN_1: 70
# 	Blocker: 55
# 	Selfish: 418
# Jugamos
# Ronda 3: DQN_1 vs. Random vs. Blocker vs. Selfish
# Entrenando: 1000 de 1000 rondas
# Entrenamiento finalizado con 1000 rondas
# Victorias acumuladas:
# 	DQN_1: 181
# 	Random: 34
# 	Blocker: 75
# 	Selfish: 710
# Jugamos
# 	Se han necesitado 4 rondas adicionales
# Ronda 4: DQN_0 vs. DQN_1 vs. Random vs. Selfish
# Entrenando: 1000 de 1000 rondas
# Entrenamiento finalizado con 1000 rondas
# Victorias acumuladas:
# 	DQN_0: 716
# 	DQN_1: 81
# ...

# %%
from competition import tournament, DQN, Blocker, IntelligentSelfish
tournament(
    agents=[DQN(name=f'DQN_{i}') for i in range(3)]+[Blocker(name=f'Blocker'), IntelligentSelfish(name=f'Selfish')],
    competitors_per_round=4,
    num_rounds=10,
    max_score=3,
    score_to_substract=1,
    max_training_rounds=700,
    min_training_rounds=300
)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 2
#       1 from competition import DQN, Blocker, IntelligentSelfish
# ----> 2 tournament(
#       3     agents=[DQN(name=f'DQN_{i}') for i in range(3)]+[Blocker(name=f'Blocker'), IntelligentSelfish(name=f'Selfish')],
#       4     competitors_per_round=4,
#       5     num_rounds=10,
#       6     max_score=3,
#       7     score_to_substract=1,
#       8     max_training_rounds=700,
#       9     min_training_rounds=300
#      10 )
#
# NameError: name 'tournament' is not defined

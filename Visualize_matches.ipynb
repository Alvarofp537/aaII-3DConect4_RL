# %%
from competition import DQN, Blocker, ConnectN3DEnv, visualize_match
import numpy as np

env = ConnectN3DEnv(num_players=4)
obs, _ = env.reset()
done, info = False, {}
i = 0
agents = [DQN(name=f'DQN_{i}') for i in range(2)]+[Blocker(name=f'Blocker_{i}') for i in range(2)]
states = []
while not done:
    if i < 4 and np.count_nonzero(env.board.grid) < i:
        print('Alguien ha fallado ya!!')
        print(env.board.grid)
        print(f"{np.count_nonzero(env.board.grid) = }, {i = }")
        raise SystemError
    # A ver a quién le toca
    current_p = env.current_player

    agent = agents[current_p - 1]
    # El agente selecciona qué acción hacer
    action = agent.select_action(env.board)
    # La hace y ve qué ha pasado con el entorno
    next_obs, reward, done, _, info = env.step(action=action)
    if reward < 0:
        print(f'Invalid action {action} performed by {agent.name}')
    # Vemos el nuevo estado del entorno para el próximo jugador
    obs = next_obs
    i += 1
    states.append(env.board.grid.copy())
    # print(f'Tablero[{i}]')
    # print(env.board.grid)
    # print()
visualize_match(states, [a.name for a in agents])
# Out:
# Cargando modelo desde ./DQN_0.pth
# Cargando modelo desde ./DQN_1.pth
# Invalid action (1, 1) performed by DQN_1
# Invalid action (1, 1) performed by DQN_0
# Invalid action (1, 1) performed by DQN_1
# Invalid action (1, 1) performed by DQN_0
# Invalid action (1, 1) performed by DQN_1
# Invalid action (1, 1) performed by DQN_0
# Invalid action (1, 1) performed by DQN_1
# Invalid action (1, 1) performed by DQN_0
# Invalid action (1, 1) performed by DQN_0
# Invalid action (1, 1) performed by DQN_1
# Invalid action (1, 1) performed by DQN_0
# Invalid action (1, 1) performed by DQN_1
# Invalid action (1, 1) performed by DQN_0
# Invalid action (1, 1) performed by DQN_1
# Invalid action (1, 1) performed by DQN_0
# Invalid action (1, 1) performed by DQN_1
# Invalid action (1, 1) performed by DQN_0
# Invalid action (1, 1) performed by DQN_1
# Invalid action (1, 1) performed by DQN_0
# Invalid action (1, 1) performed by DQN_1
# Invalid action (1, 1) performed by DQN_0
# Invalid action (1, 1) performed by DQN_1
# Invalid action (1, 1) performed by DQN_0
# Invalid action (1, 1) performed by DQN_1
# Invalid action (1, 1) performed by DQN_0
# Invalid action (1, 1) performed by DQN_1
# Invalid action (1, 1) performed by DQN_1
# Invalid action (1, 1) performed by DQN_0
# Invalid action (1, 1) performed by DQN_0
# Invalid action (1, 1) performed by DQN_1
# Invalid action (1, 0) performed by DQN_0
# Invalid action (1, 0) performed by DQN_1
# Invalid action (1, 0) performed by DQN_0
# Invalid action (1, 0) performed by DQN_1
# Invalid action (1, 0) performed by DQN_0
# Invalid action (1, 1) performed by DQN_1
# Invalid action (1, 0) performed by DQN_0
# Invalid action (1, 0) performed by DQN_1
# Invalid action (1, 0) performed by DQN_0
# Invalid action (1, 1) performed by DQN_1
# Invalid action (1, 0) performed by DQN_0
# Invalid action (1, 0) performed by DQN_1
# Invalid action (1, 0) performed by DQN_0
# Invalid action (1, 0) performed by DQN_1
# Invalid action (1, 0) performed by DQN_0
# Invalid action (1, 0) performed by DQN_1
# Invalid action (1, 0) performed by DQN_0
# Invalid action (1, 0) performed by DQN_1
# Invalid action (1, 0) performed by DQN_1
# Invalid action (1, 0) performed by DQN_0
# Invalid action (1, 0) performed by DQN_1
# Invalid action (1, 0) performed by DQN_0
# Invalid action (1, 0) performed by DQN_1
# Invalid action (1, 0) performed by DQN_0
# Invalid action (1, 0) performed by DQN_1
# Invalid action (1, 0) performed by DQN_0
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[6], line 33
#      29     states.append(env.board.grid.copy())
#      30     # print(f'Tablero[{i}]')
#      31     # print(env.board.grid)
#      32     # print()
# ---> 33 visualize_match(states, [a.name for a in agents])
#
# TypeError: visualize_match() takes 1 positional argument but 2 were given

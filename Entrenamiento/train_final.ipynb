# %% [markdown]
# #### Todos los que tenemos
# Primero train, luego otra de control

# %%
from competition import tournament, DQN, PPO, Selfish, Blocker, IntelligentSelfish, Greedier, BlockerDeluxe, Minimax

# Lista de agentes para el torneo
agents = [
    DQN(name='DQN_0'),
    PPO(name='PPO_1'),
    Selfish(name=f'Selfish'),
    Blocker(name=f'Blocker'),
    IntelligentSelfish(name=f'IntelligentSelfish'),
    BlockerDeluxe(name=f'BlockerDeluxe')
]

# Configuración del torneo
tournament(
    agents=agents,
    competitors_per_round=4,
    num_rounds=10,
    max_score=3,
    score_to_substract=1,
    min_training_rounds=500,
    max_training_rounds=500,
)
# Out:
# Cargando modelo desde ./DQN_0.pth
# Ronda 1: DQN_0 vs. PPO_1 vs. Selfish vs. IntelligentSelfish
# Entrenando: 500 de 500 rondas
# Entrenamiento finalizado con 500 rondas
# Victorias acumuladas:
# 	Selfish: 116
# 	IntelligentSelfish: 147
# 	PPO_1: 96
# 	DQN_0: 141
# Jugamos
# Ronda 2: DQN_0 vs. Selfish vs. Blocker vs. IntelligentSelfish
# Entrenando: 500 de 500 rondas
# Entrenamiento finalizado con 500 rondas
# Victorias acumuladas:
# 	Blocker: 95
# 	Selfish: 213
# 	IntelligentSelfish: 103
# 	DQN_0: 89
# Jugamos
# 	Se han necesitado 10 rondas adicionales
# Ronda 3: PPO_1 vs. Selfish vs. IntelligentSelfish vs. BlockerDeluxe
# Entrenando: 500 de 500 rondas
# Entrenamiento finalizado con 500 rondas
# Victorias acumuladas:
# 	BlockerDeluxe: 28
# 	Selfish: 184
# 	IntelligentSelfish: 167
# 	PPO_1: 121
# Jugamos
# Ronda 4: DQN_0 vs. PPO_1 vs. Blocker vs. IntelligentSelfish
# Entrenando: 500 de 500 rondas
# Entrenamiento finalizado con 500 rondas
# Victorias acumuladas:
# 	PPO_1: 124
# ...

# %%
from competition import tournament, DQN, PPO, Selfish, Blocker, IntelligentSelfish, Minimax

# Lista de agentes para el torneo
agents = [
    DQN(name='DQN_0'),
    PPO(name='PPO_1'),
    Selfish(name=f'Selfish'),
    Blocker(name=f'Blocker'),
    IntelligentSelfish(name=f'IntelligentSelfish'),
    Minimax(name=f'Minimax', depth=3)
]

# Configuración del torneo
tournament(
    agents=agents,
    competitors_per_round=4,
    num_rounds=10,
    max_score=3,
    score_to_substract=1,
    max_training_rounds=0,
)
# Out:
# Cargando modelo desde ./DQN_0.pth
# Ronda 1: DQN_0 vs. PPO_1 vs. Selfish vs. Minimax
# Jugamos
# Ronda 2: DQN_0 vs. PPO_1 vs. Blocker vs. Minimax
# Jugamos
# Ronda 3: DQN_0 vs. Blocker vs. IntelligentSelfish vs. Minimax
# Jugamos
# Ronda 4: PPO_1 vs. Selfish vs. Blocker vs. Minimax
# Jugamos
# Ronda 5: DQN_0 vs. PPO_1 vs. Selfish vs. Blocker
# Jugamos
# Ronda 6: PPO_1 vs. Selfish vs. Blocker vs. IntelligentSelfish
# Jugamos
# 	Se han necesitado 2 rondas adicionales
# Ronda 7: PPO_1 vs. Selfish vs. IntelligentSelfish vs. Minimax
# Jugamos
# Ronda 8: DQN_0 vs. Selfish vs. Blocker vs. IntelligentSelfish
# Jugamos
# Ronda 9: PPO_1 vs. Blocker vs. IntelligentSelfish vs. Minimax
# Jugamos
# Ronda 10: Selfish vs. Blocker vs. IntelligentSelfish vs. Minimax
# Jugamos
# Ronda 11: DQN_0 vs. Selfish vs. IntelligentSelfish vs. Minimax
# Jugamos
# 	Se ha necesitado una ronda adicional
# Ronda 12: DQN_0 vs. Selfish vs. Blocker vs. Minimax
# Jugamos
# 	Se han necesitado 72 rondas adicionales
# ...

# %%
from competition import tournament, Selfish, Blocker, IntelligentSelfish, Greedier, Minimax

# Lista de agentes para el torneo
agents = [
    Selfish(name=f'Selfish'),
    Blocker(name=f'Blocker'),
    IntelligentSelfish(name=f'IntelligentSelfish'),
    Greedier(name=f'Greedier'),
    Minimax(name=f'Minimax', depth=3)
]

# Configuración del torneo
tournament(
    agents=agents,
    competitors_per_round=4,
    num_rounds=10,
    max_score=3,
    score_to_substract=1,
    max_training_rounds=0,
)
# Out:
# Ronda 1: Blocker vs. IntelligentSelfish vs. Greedier vs. Minimax
# Jugamos
# Ronda 2: Selfish vs. Blocker vs. Greedier vs. Minimax
# Jugamos
# Ronda 3: Selfish vs. IntelligentSelfish vs. Greedier vs. Minimax
# Jugamos
# Ronda 4: Selfish vs. Blocker vs. IntelligentSelfish vs. Minimax
# Jugamos
# Ronda 5: Selfish vs. Blocker vs. IntelligentSelfish vs. Greedier
# Jugamos
#
# CLASIFICACIÓN FINAL
# Agente |  Puntos
# ------------------
# Minimax |       7
# Greedier |       6
# Selfish |       5
# IntelligentSelfish |       4
# Blocker |       0
# ------------------

# %%
from competition import tournament, DQN, PPO

# Lista de agentes para el torneo
agents = [
    DQN(name='DQN_0'),
    PPO(name='PPO_0'),
    DQN(name='DQN_1'),
    PPO(name='PPO_1'),
]

# Configuración del torneo
tournament(
    agents=agents,
    competitors_per_round=4,
    num_rounds=10,
    max_score=3,
    score_to_substract=1,
    max_training_rounds=1000,
)
# Out:
# Cargando modelo desde ./DQN_0.pth
# Cargando modelo desde ./DQN_1.pth
# Ronda 1: DQN_0 vs. PPO_0 vs. DQN_1 vs. PPO_1
# Entrenando: 1000 de 1000 rondas
# Entrenamiento finalizado con 1000 rondas
# Victorias acumuladas:
# 	DQN_0: 1
# 	PPO_0: 478
# 	PPO_1: 520
# 	DQN_1: 1
# Jugamos
#
# CLASIFICACIÓN FINAL
# Agente |  Puntos
# ------------------
#  PPO_0 |       3
#  PPO_1 |       2
#  DQN_0 |       0
#  DQN_1 |       0
# ------------------

# %%
from competition import tournament, DQN, PPO

# Lista de agentes para el torneo
agents = [
    DQN(name='DQN_0'),
    PPO(name='PPO_0'),
    DQN(name='DQN_1'),
    PPO(name='PPO_1'),
]

# Configuración del torneo
tournament(
    agents=agents,
    competitors_per_round=4,
    num_rounds=10,
    max_score=3,
    score_to_substract=1,
    max_training_rounds=0,
)
# Out:
# Cargando modelo desde ./DQN_0.pth
# Cargando modelo desde ./DQN_1.pth
# Ronda 1: DQN_0 vs. PPO_0 vs. DQN_1 vs. PPO_1
# Jugamos
#
# CLASIFICACIÓN FINAL
# Agente |  Puntos
# ------------------
#  PPO_1 |       3
#  DQN_0 |       0
#  PPO_0 |       0
#  DQN_1 |       0
# ------------------

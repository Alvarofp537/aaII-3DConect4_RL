# %% [markdown]
# #### Entrenamiento solas

# %%
from competition import tournament, PPO
tournament(
    agents=[PPO(name=f'PPO_{i}') for i in range(4)],
    competitors_per_round=4,
    num_rounds=10,
    max_score=10,
    score_to_substract=5,
    min_training_rounds=50000
)
# Out:
# Ronda 1: PPO_0 vs. PPO_1 vs. PPO_2 vs. PPO_3
# Entrenando: 50000 de 50000 rondas
# Entrenamiento finalizado con 50000 rondas
# Victorias acumuladas:
# 	PPO_2: 0
# 	PPO_1: 16507
# 	PPO_3: 16721
# 	PPO_0: 16772
# Jugamos
#
# CLASIFICACIÓN FINAL
# Agente |  Puntos
# ------------------
#  PPO_1 |      10
#  PPO_0 |       0
#  PPO_2 |       0
#  PPO_3 |       0
# ------------------

# %% [markdown]
# #### Competición 2 PPO vs 3 Random
#
# Aprende lo básico

# %%
from competition import tournament, RandomAgent, PPO
tournament(
    agents=[RandomAgent(name=f'Random_{i}') for i in range(3)]+[PPO(name=f'PPO_{i}') for i in range(2)],
    competitors_per_round=4,
    num_rounds=10,
    max_score=10,
    score_to_substract=5,
)
# Out:
# Ronda 1: Random_0 vs. Random_2 vs. PPO_0 vs. PPO_1
# Entrenando: 1630 de 1630 rondas
# Entrenamiento finalizado con 1630 rondas
# Victorias acumuladas:
# 	Random_2: 17
# 	PPO_1: 793
# 	PPO_0: 809
# 	Random_0: 11
# Jugamos
# 	Se han necesitado 9 rondas adicionales
# Ronda 2: Random_0 vs. Random_1 vs. Random_2 vs. PPO_0
# Entrenando: 67 de 67 rondas
# Entrenamiento finalizado con 67 rondas
# Victorias acumuladas:
# 	Random_2: 3
# 	PPO_0: 52
# 	Random_1: 6
# 	Random_0: 6
# Jugamos
# Ronda 3: Random_1 vs. Random_2 vs. PPO_0 vs. PPO_1
# Entrenando: 504 de 504 rondas
# Entrenamiento finalizado con 504 rondas
# Victorias acumuladas:
# 	PPO_1: 254
# 	Random_2: 5
# 	PPO_0: 241
# 	Random_1: 4
# Jugamos
# Ronda 4: Random_0 vs. Random_1 vs. PPO_0 vs. PPO_1
# Entrenando: 205 de 205 rondas
# Entrenamiento finalizado con 205 rondas
# Victorias acumuladas:
# 	Random_1: 3
# 	PPO_1: 96
# 	Random_0: 2
# 	PPO_0: 104
# Jugamos
# Ronda 5: Random_0 vs. Random_1 vs. Random_2 vs. PPO_1
# Entrenando: 491 de 491 rondas
# Entrenamiento finalizado con 491 rondas
# Victorias acumuladas:
# 	Random_0: 39
# 	Random_1: 25
# 	PPO_1: 387
# 	Random_2: 40
# Jugamos
#
# CLASIFICACIÓN FINAL
# Agente |  Puntos
# ------------------
#  PPO_1 |      40
#  PPO_0 |      20
# Random_1 |       5
# Random_2 |       5
# Random_0 |      -5
# ------------------

# %% [markdown]
# #### Competición 3 PPO vs 3 Blocker
#
# Aprende a ganar aunque le bloqueen

# %%
from competition import tournament, PPO, Blocker
tournament(
    agents=[PPO(name=f'PPO_{i}') for i in range(3)]+[Blocker(name=f'Blocker_{i}') for i in range(3)],
    competitors_per_round=4,
    num_rounds=10,
    max_score=3,
    score_to_substract=1,
    min_training_rounds=300,
    max_training_rounds=700
)
# Out:
# Ronda 1: PPO_0 vs. PPO_1 vs. Blocker_0 vs. Blocker_2
# Entrenando: 300 de 300 rondas
# Entrenamiento finalizado con 300 rondas
# Victorias acumuladas:
# 	Blocker_2: 71
# 	PPO_1: 77
# 	PPO_0: 104
# 	Blocker_0: 39
# Jugamos
# 	Se han necesitado 9 rondas adicionales
# Ronda 2: PPO_0 vs. PPO_2 vs. Blocker_0 vs. Blocker_2
# Entrenando: 608 de 608 rondas
# Entrenamiento finalizado con 608 rondas
# Victorias acumuladas:
# 	Blocker_2: 155
# 	PPO_0: 101
# 	Blocker_0: 164
# 	PPO_2: 80
# Jugamos
# 	Se han necesitado 12 rondas adicionales
# Ronda 3: PPO_0 vs. PPO_1 vs. PPO_2 vs. Blocker_1
# Entrenando: 300 de 300 rondas
# Entrenamiento finalizado con 300 rondas
# Victorias acumuladas:
# 	PPO_0: 0
# 	PPO_1: 195
# 	PPO_2: 99
# 	Blocker_1: 6
# Jugamos
# Ronda 4: PPO_1 vs. PPO_2 vs. Blocker_0 vs. Blocker_1
# Entrenando: 656 de 656 rondas
# Entrenamiento finalizado con 656 rondas
# Victorias acumuladas:
# 	PPO_2: 33
# 	Blocker_0: 159
# 	Blocker_1: 161
# 	PPO_1: 138
# Jugamos
# 	Se han necesitado 22 rondas adicionales
# Ronda 5: PPO_0 vs. PPO_1 vs. Blocker_0 vs. Blocker_1
# Entrenando: 700 de 700 rondas
# Entrenamiento finalizado con 700 rondas
# Victorias acumuladas:
# 	PPO_0: 58
# 	Blocker_0: 136
# 	Blocker_1: 131
# 	PPO_1: 296
# Jugamos
# 	Se han necesitado 9 rondas adicionales
# Ronda 6: PPO_1 vs. Blocker_0 vs. Blocker_1 vs. Blocker_2
# Entrenando: 300 de 300 rondas
# Entrenamiento finalizado con 300 rondas
# Victorias acumuladas:
# 	Blocker_1: 44
# 	PPO_1: 32
# 	Blocker_0: 60
# 	Blocker_2: 60
# Jugamos
# 	Se han necesitado 2 rondas adicionales
# Ronda 7: PPO_0 vs. PPO_2 vs. Blocker_0 vs. Blocker_1
# Entrenando: 682 de 682 rondas
# Entrenamiento finalizado con 682 rondas
# Victorias acumuladas:
# 	Blocker_0: 165
# 	PPO_0: 73
# 	Blocker_1: 165
# 	PPO_2: 92
# Jugamos
# 	Se han necesitado 2 rondas adicionales
# Ronda 8: PPO_0 vs. PPO_1 vs. PPO_2 vs. Blocker_2
# Entrenando: 420 de 420 rondas
# Entrenamiento finalizado con 420 rondas
# Victorias acumuladas:
# 	PPO_0: 1
# 	PPO_1: 252
# 	PPO_2: 157
# 	Blocker_2: 10
# Jugamos
# Ronda 9: PPO_1 vs. PPO_2 vs. Blocker_0 vs. Blocker_2
# Entrenando: 300 de 300 rondas
# Entrenamiento finalizado con 300 rondas
# Victorias acumuladas:
# 	PPO_1: 48
# 	Blocker_2: 71
# 	PPO_2: 21
# 	Blocker_0: 75
# Jugamos
# Ronda 10: PPO_2 vs. Blocker_0 vs. Blocker_1 vs. Blocker_2
# Entrenando: 300 de 300 rondas
# Entrenamiento finalizado con 300 rondas
# Victorias acumuladas:
# 	Blocker_2: 38
# 	PPO_2: 26
# 	Blocker_0: 58
# 	Blocker_1: 53
# Jugamos
# Ronda 11: PPO_1 vs. PPO_2 vs. Blocker_1 vs. Blocker_2
# Entrenando: 300 de 300 rondas
# Entrenamiento finalizado con 300 rondas
# Victorias acumuladas:
# 	Blocker_2: 72
# 	Blocker_1: 61
# 	PPO_2: 20
# 	PPO_1: 64
# Jugamos
# 	Se han necesitado 6 rondas adicionales
# Ronda 12: PPO_0 vs. PPO_1 vs. PPO_2 vs. Blocker_0
# Entrenando: 700 de 700 rondas
# Entrenamiento finalizado con 700 rondas
# Victorias acumuladas:
# 	Blocker_0: 9
# 	PPO_0: 1
# 	PPO_2: 254
# 	PPO_1: 435
# Jugamos
# Ronda 13: PPO_0 vs. Blocker_0 vs. Blocker_1 vs. Blocker_2
# Entrenando: 611 de 611 rondas
# Entrenamiento finalizado con 611 rondas
# Victorias acumuladas:
# 	Blocker_2: 99
# 	Blocker_0: 100
# 	PPO_0: 36
# 	Blocker_1: 102
# Jugamos
# 	Se han necesitado 22 rondas adicionales
# Ronda 14: PPO_0 vs. PPO_2 vs. Blocker_1 vs. Blocker_2
# Entrenando: 700 de 700 rondas
# Entrenamiento finalizado con 700 rondas
# Victorias acumuladas:
# 	PPO_0: 50
# 	Blocker_1: 170
# 	PPO_2: 75
# 	Blocker_2: 170
# Jugamos
# Ronda 15: PPO_0 vs. PPO_1 vs. Blocker_1 vs. Blocker_2
# Entrenando: 300 de 300 rondas
# Entrenamiento finalizado con 300 rondas
# Victorias acumuladas:
# 	PPO_0: 31
# 	Blocker_2: 62
# 	Blocker_1: 63
# 	PPO_1: 104
# Jugamos
# 	Se ha necesitado una ronda adicional
#
# CLASIFICACIÓN FINAL
# Agente |  Puntos
# ------------------
#  PPO_1 |      20
# Blocker_0 |      15
# Blocker_1 |      15
#  PPO_2 |       6
# Blocker_2 |       6
#  PPO_0 |       0
# ------------------

# %% [markdown]
# #### Competición 3 PPO vs vs 3 Selfish
#
# Aprende bloquear

# %%
from competition import tournament, PPO, Selfish
tournament(
    agents=[PPO(name=f'PPO_{i}') for i in range(3)]+[Selfish(name=f'Selfish_{i}') for i in range(3)],
    competitors_per_round=4,
    num_rounds=10,
    max_score=10,
    score_to_substract=5,
    max_training_rounds=500
)
# Out:
# Ronda 1: PPO_0 vs. PPO_1 vs. Selfish_0 vs. Selfish_2
# Entrenando: 500 de 500 rondas
# Entrenamiento finalizado con 500 rondas
# Victorias acumuladas:
# 	PPO_1: 223
# 	Selfish_2: 41
# 	PPO_0: 198
# 	Selfish_0: 38
# Jugamos
# Ronda 2: PPO_0 vs. Selfish_0 vs. Selfish_1 vs. Selfish_2
# Entrenando: 324 de 324 rondas
# Entrenamiento finalizado con 324 rondas
# Victorias acumuladas:
# 	Selfish_2: 27
# 	PPO_0: 244
# 	Selfish_1: 28
# 	Selfish_0: 25
# Jugamos
# Ronda 3: PPO_2 vs. Selfish_0 vs. Selfish_1 vs. Selfish_2
# Entrenando: 26 de 26 rondas
# Entrenamiento finalizado con 26 rondas
# Victorias acumuladas:
# 	Selfish_2: 6
# 	Selfish_0: 5
# 	PPO_2: 5
# 	Selfish_1: 10
# Jugamos
# Ronda 4: PPO_1 vs. PPO_2 vs. Selfish_0 vs. Selfish_2
# Entrenando: 500 de 500 rondas
# Entrenamiento finalizado con 500 rondas
# Victorias acumuladas:
# 	PPO_1: 124
# 	PPO_2: 131
# 	Selfish_2: 126
# 	Selfish_0: 119
# Jugamos
# Ronda 5: PPO_0 vs. PPO_1 vs. PPO_2 vs. Selfish_1
# Entrenando: 500 de 500 rondas
# Entrenamiento finalizado con 500 rondas
# Victorias acumuladas:
# 	PPO_0: 157
# 	PPO_1: 137
# 	PPO_2: 72
# 	Selfish_1: 134
# Jugamos
# Ronda 6: PPO_1 vs. PPO_2 vs. Selfish_0 vs. Selfish_1
# Entrenando: 500 de 500 rondas
# Entrenamiento finalizado con 500 rondas
# Victorias acumuladas:
# 	PPO_1: 129
# 	Selfish_1: 128
# 	Selfish_0: 133
# 	PPO_2: 110
# Jugamos
# Ronda 7: PPO_0 vs. PPO_2 vs. Selfish_1 vs. Selfish_2
# Entrenando: 500 de 500 rondas
# Entrenamiento finalizado con 500 rondas
# Victorias acumuladas:
# 	Selfish_2: 37
# 	PPO_0: 291
# 	PPO_2: 132
# 	Selfish_1: 40
# Jugamos
# Ronda 8: PPO_0 vs. PPO_2 vs. Selfish_0 vs. Selfish_1
# Entrenando: 500 de 500 rondas
# Entrenamiento finalizado con 500 rondas
# Victorias acumuladas:
# 	PPO_2: 110
# 	Selfish_0: 42
# 	PPO_0: 297
# 	Selfish_1: 51
# Jugamos
# Ronda 9: PPO_1 vs. Selfish_0 vs. Selfish_1 vs. Selfish_2
# Entrenando: 19 de 19 rondas
# Entrenamiento finalizado con 19 rondas
# Victorias acumuladas:
# 	Selfish_1: 7
# 	Selfish_0: 6
# 	PPO_1: 2
# 	Selfish_2: 4
# Jugamos
# Ronda 10: PPO_0 vs. PPO_1 vs. PPO_2 vs. Selfish_0
# Entrenando: 500 de 500 rondas
# Entrenamiento finalizado con 500 rondas
# Victorias acumuladas:
# 	Selfish_0: 160
# 	PPO_1: 133
# 	PPO_0: 154
# 	PPO_2: 53
# Jugamos
# Ronda 11: PPO_0 vs. PPO_1 vs. PPO_2 vs. Selfish_2
# Entrenando: 329 de 329 rondas
# Entrenamiento finalizado con 329 rondas
# Victorias acumuladas:
# 	PPO_2: 27
# 	PPO_1: 102
# 	PPO_0: 80
# 	Selfish_2: 120
# Jugamos
# Ronda 12: PPO_0 vs. PPO_2 vs. Selfish_0 vs. Selfish_2
# Entrenando: 421 de 421 rondas
# Entrenamiento finalizado con 421 rondas
# Victorias acumuladas:
# 	Selfish_0: 45
# 	PPO_0: 275
# 	Selfish_2: 39
# 	PPO_2: 62
# Jugamos
# Ronda 13: PPO_1 vs. PPO_2 vs. Selfish_1 vs. Selfish_2
# Entrenando: 500 de 500 rondas
# Entrenamiento finalizado con 500 rondas
# Victorias acumuladas:
# 	PPO_1: 142
# 	Selfish_2: 162
# 	PPO_2: 62
# 	Selfish_1: 134
# Jugamos
# Ronda 14: PPO_0 vs. PPO_1 vs. Selfish_0 vs. Selfish_1
# Entrenando: 500 de 500 rondas
# Entrenamiento finalizado con 500 rondas
# Victorias acumuladas:
# 	PPO_0: 187
# 	Selfish_0: 39
# 	Selfish_1: 51
# 	PPO_1: 223
# Jugamos
# Ronda 15: PPO_0 vs. PPO_1 vs. Selfish_1 vs. Selfish_2
# Entrenando: 500 de 500 rondas
# Entrenamiento finalizado con 500 rondas
# Victorias acumuladas:
# 	PPO_1: 194
# 	PPO_0: 222
# 	Selfish_1: 43
# 	Selfish_2: 41
# Jugamos
#
# CLASIFICACIÓN FINAL
# Agente |  Puntos
# ------------------
#  PPO_0 |      60
#  PPO_1 |      60
# Selfish_0 |      10
# Selfish_1 |      10
# Selfish_2 |      10
#  PPO_2 |       0
# ------------------

# %% [markdown]
# #### Competición 3 PPO vs 3 Minimax
#
# Jugamos contra minimax (inteligentes)

# %%
from competition import tournament, PPO, Minimax
tournament(
    agents=[PPO(name=f'PPO_{i}') for i in range(3)]+[Minimax(name=f'Minimax_{i}') for i in range(3)],
    competitors_per_round=4,
    num_rounds=10,
    max_score=10,
    score_to_substract=5,
    min_training_rounds=300,
    max_training_rounds=600
)
# Out:
# Ronda 1: PPO_0 vs. PPO_1 vs. PPO_2 vs. Minimax_0
# Entrenando: 300 de 300 rondas
# Entrenamiento finalizado con 300 rondas
# Victorias acumuladas:
# 	PPO_1: 149
# 	PPO_0: 143
# 	Minimax_0: 0
# 	PPO_2: 8
# Jugamos
# Ronda 2: PPO_1 vs. PPO_2 vs. Minimax_0 vs. Minimax_2
# Entrenando: 150 de 457 rondas
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[5], line 2
#       1 from competition import tournament, PPO, Minimax
# ----> 2 tournament(
#       3     agents=[PPO(name=f'PPO_{i}') for i in range(3)]+[Minimax(name=f'Minimax_{i}') for i in range(3)],
#       4     competitors_per_round=4,
#       5     num_rounds=10,
#       6     max_score=10,
#       7     score_to_substract=5,
#       8     min_training_rounds=300,
#       9     max_training_rounds=600
#      10 )
#
# File ~/Escritorio/aaII-3DConect4_RL/competition.py:124, in tournament(agents, competitors_per_round, num_rounds, max_score, score_to_substract, max_training_rounds, min_training_rounds, imprimir)
#     122 for i in range(1, train_rounds + 1):
#     123     random.shuffle(group)
# --> 124     winner = play_episode(env=env, agents=group, learn=True, imprimir=imprimir)
#     125     if winner:
#     126         train_winners[winner.name] += 1
#
# File ~/Escritorio/aaII-3DConect4_RL/competition.py:43, in play_episode(env, agents, learn, imprimir)
#      41 agent = agents[current_p - 1]
#      42 # El agente selecciona qué acción hacer
# ---> 43 action = agent.select_action(env.board)
#      44 # La hace y ve qué ha pasado con el entorno
#      45 next_obs, reward, done, _, info = env.step(action=action)
#
# File ~/Escritorio/aaII-3DConect4_RL/Minimax.py:20, in select_action(self, board)
#       0 <Error retrieving source code with stack_data see ipython/ipython#13598>
#
# File ~/Escritorio/aaII-3DConect4_RL/Minimax.py:46, in minimax(self, board, depth, maximizing, current_player, alpha, beta)
#      39 depth = self.depth
#      41 args = [
#      42     (move, board, current_player, depth, self.transposition_table, self.pos)
#      43     for move in legal_moves
#      44 ]
# ---> 46 if self.use_multiprocessing:
#      47     with ProcessPoolExecutor() as executor:
#      48         results = list(executor.map(evaluate_move_wrapper, args))
#
# File ~/Escritorio/aaII-3DConect4_RL/Minimax.py:46, in minimax(self, board, depth, maximizing, current_player, alpha, beta)
#      39 depth = self.depth
#      41 args = [
#      42     (move, board, current_player, depth, self.transposition_table, self.pos)
#      43     for move in legal_moves
#      44 ]
# ---> 46 if self.use_multiprocessing:
#      47     with ProcessPoolExecutor() as executor:
#      48         results = list(executor.map(evaluate_move_wrapper, args))
#
# File ~/Escritorio/aaII-3DConect4_RL/Minimax.py:46, in minimax(self, board, depth, maximizing, current_player, alpha, beta)
#      39 depth = self.depth
#      41 args = [
#      42     (move, board, current_player, depth, self.transposition_table, self.pos)
#      43     for move in legal_moves
#      44 ]
# ---> 46 if self.use_multiprocessing:
#      47     with ProcessPoolExecutor() as executor:
#      48         results = list(executor.map(evaluate_move_wrapper, args))
#
# File ~/Escritorio/aaII-3DConect4_RL/Minimax.py:33, in minimax(self, board, depth, maximizing, current_player, alpha, beta)
#      32 def select_action(self, board: ConnectNBoard3D) -> Tuple[int, int]:
# ---> 33     count = np.count_nonzero(board.grid)
#      34     if self.pos is None and count < 4:
#      35         self.pos = count + 1
#
# File ~/Escritorio/aaII-3DConect4_RL/Minimax.py:137, in custom_reward(self, board, player_id)
#     134 after = (x + length * dx, y + length * dy, z + length * dz)
#     136 open_before = (0 <= before[0] < gx and 0 <= before[1] < gy and 0 <= before[2] < gz and grid[before[2], before[0], before[1]] == 0)
# --> 137 open_after  = (0 <= after[0] < gx and 0 <= after[1] < gy and 0 <= after[2] < gz and grid[after[2], after[0], after[1]] == 0)
#     139 total_open_ends = int(open_before) + int(open_after)
#     141 if exact:
#
# File ~/Escritorio/aaII-3DConect4_RL/Minimax.py:76, in count_connections(self, board, player_id, length, open_ends, exact)
#      73 best_action = None
#      75 for move in board.legal_moves():
# ---> 76     temp_board = board.clone()
#      77     try:
#      78         temp_board.place_token(current_player, *move)
#
# KeyboardInterrupt:

# %% [markdown]
# #### Competición 2 PPO vs 1 Random vs 1 Blocker vs 1 Selfish vs 1 Minimax
#
# Todos juntos a aprender

# %%
from competition import tournament, PPO, RandomAgent, Blocker, Selfish, Minimax
tournament(
    agents=[PPO(name=f'PPO_{i}') for i in range(2)]+[RandomAgent(name=f'Random'), Blocker(name=f'Blocker'), Selfish(name=f'Selfish')],#, Minimax(name=f'Minimax',depth= 3)],
    competitors_per_round=4,
    num_rounds=10,
    max_score=3,
    score_to_substract=1,
    min_training_rounds=100,
)
# Out:
# Ronda 1: PPO_1 vs. Random vs. Blocker vs. Selfish
# Entrenando: 614 de 614 rondas
# Entrenamiento finalizado con 614 rondas
# Victorias acumuladas:
# 	Random: 9
# 	Blocker: 24
# 	PPO_1: 295
# 	Selfish: 286
# Jugamos
# Ronda 2: PPO_0 vs. PPO_1 vs. Random vs. Selfish
# Entrenando: 569 de 569 rondas
# Entrenamiento finalizado con 569 rondas
# Victorias acumuladas:
# 	PPO_1: 166
# 	Selfish: 204
# 	PPO_0: 199
# 	Random: 0
# Jugamos
# Ronda 3: PPO_0 vs. PPO_1 vs. Blocker vs. Selfish
# Entrenando: 711 de 711 rondas
# Entrenamiento finalizado con 711 rondas
# Victorias acumuladas:
# 	Blocker: 8
# 	PPO_1: 398
# 	PPO_0: 281
# 	Selfish: 24
# Jugamos
# Ronda 4: PPO_0 vs. Random vs. Blocker vs. Selfish
# Entrenando: 136 de 136 rondas
# Entrenamiento finalizado con 136 rondas
# Victorias acumuladas:
# 	Random: 3
# 	Blocker: 10
# 	Selfish: 63
# 	PPO_0: 60
# Jugamos
# 	Se han necesitado 16 rondas adicionales
# Ronda 5: PPO_0 vs. PPO_1 vs. Random vs. Blocker
# Entrenando: 222 de 222 rondas
# Entrenamiento finalizado con 222 rondas
# Victorias acumuladas:
# 	PPO_1: 102
# 	Random: 11
# 	Blocker: 109
# 	PPO_0: 0
# Jugamos
#
# CLASIFICACIÓN FINAL
# Agente |  Puntos
# ------------------
#  PPO_1 |      11
# Selfish |       6
# Blocker |       4
#  PPO_0 |       3
# Random |       1
# ------------------

# %%
from competition import tournament, PPO, Blocker, IntelligentSelfish
tournament(
    agents=[PPO(name=f'PPO_{i}') for i in range(3)]+[Blocker(name=f'Blocker'), IntelligentSelfish(name=f'Selfish')],
    competitors_per_round=4,
    num_rounds=10,
    max_score=3,
    score_to_substract=1,
    max_training_rounds=700,
    min_training_rounds=300
)
# Out:
# Ronda 1: PPO_0 vs. PPO_1 vs. PPO_2 vs. Selfish
# Entrenando: 700 de 700 rondas
# Entrenamiento finalizado con 700 rondas
# Victorias acumuladas:
# 	Selfish: 226
# 	PPO_2: 69
# 	PPO_1: 170
# 	PPO_0: 235
# Jugamos
# Ronda 2: PPO_0 vs. PPO_2 vs. Blocker vs. Selfish
# Entrenando: 300 de 300 rondas
# Entrenamiento finalizado con 300 rondas
# Victorias acumuladas:
# 	Blocker: 68
# 	Selfish: 119
# 	PPO_2: 39
# 	PPO_0: 62
# Jugamos
# 	Se han necesitado 3 rondas adicionales
# Ronda 3: PPO_1 vs. PPO_2 vs. Blocker vs. Selfish
# Entrenando: 700 de 700 rondas
# Entrenamiento finalizado con 700 rondas
# Victorias acumuladas:
# 	PPO_2: 45
# 	PPO_1: 126
# 	Selfish: 408
# 	Blocker: 98
# Jugamos
# Ronda 4: PPO_0 vs. PPO_1 vs. Blocker vs. Selfish
# Entrenando: 300 de 300 rondas
# Entrenamiento finalizado con 300 rondas
# Victorias acumuladas:
# 	Blocker: 50
# 	PPO_0: 43
# 	PPO_1: 120
# 	Selfish: 87
# Jugamos
# 	Se han necesitado 5 rondas adicionales
# Ronda 5: PPO_0 vs. PPO_1 vs. PPO_2 vs. Blocker
# Entrenando: 700 de 700 rondas
# Entrenamiento finalizado con 700 rondas
# Victorias acumuladas:
# 	PPO_0: 5
# 	PPO_2: 260
# 	PPO_1: 432
# 	Blocker: 3
# Jugamos
#
# CLASIFICACIÓN FINAL
# Agente |  Puntos
# ------------------
# Selfish |      12
#  PPO_1 |       6
#  PPO_0 |       2
#  PPO_2 |       2
# Blocker |       2
# ------------------
